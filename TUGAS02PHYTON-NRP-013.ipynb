# %%
import pandas as pd

# %%
suhu_dan_kelembaban=pd.read_csv('http://data.bandung.go.id/dataset/f2112fc0-f2b8-436e-940f-ed0c377eb8ed/resource/983e8225-ceb0-4630-b767-e92f792e77b4/download/rata-rata-suhu-dan-kelembaban-udara-menurut-bulan-di-kota-bandung-2017.csv')

# %%
suhu_dan_kelembaban.head()
# Out:
#    Nomor     Bulan  Temperatur Rata-rata (oC)  Temperatur Maksimal (oC)  \
# 0      1   Januari                       24.2                      29.1
# 1      2  Februari                       23.0                      28.3
# 2      3     Maret                       23.3                      29.2
# 3      4     April                       23.6                      28.2
# 4      5       Mei                       23.9                      29.5
#
#    Temperatur Minimal (oC)  Jumlah Curah Hujan (mm)  Hari Hujan (hari)  \
# 0                     21.0                     65.3                 23
# 1                     20.4                    199.3                 24
# 2                     20.2                    389.3                 27
# 3                     20.7                    220.2                 27
# 4                     20.2                    222.3                 18
#
#    LPM/Sunshine Duration (%)
# 0                         53
# 1                         40
# ...

# %%
suhu_dan_kelembaban.tail()
# Out:
#     Nomor      Bulan  Temperatur Rata-rata (oC)  Temperatur Maksimal (oC)  \
# 7       8    Agustus                       23.3                      29.8
# 8       9  September                       23.7                      30.5
# 9      10    Oktober                       23.4                      29.8
# 10     11   November                       23.1                      28.7
# 11     12   Desember                       23.9                      29.3
#
#     Temperatur Minimal (oC)  Jumlah Curah Hujan (mm)  Hari Hujan (hari)  \
# 7                      18.8                     48.4                  6
# 8                      19.4                     90.8                 12
# 9                      20.2                    345.3                 24
# 10                     20.4                    442.2                 25
# 11                     20.7                    129.9                 20
#
#     LPM/Sunshine Duration (%)
# 7                          77
# ...

# %%
suhu_dan_kelembaban.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
# Nomor                        12 non-null int64
# Bulan                        12 non-null object
# Temperatur Rata-rata (oC)    12 non-null float64
# Temperatur Maksimal (oC)     12 non-null float64
# Temperatur Minimal (oC)      12 non-null float64
# Jumlah Curah Hujan (mm)      12 non-null float64
# Hari Hujan (hari)            12 non-null int64
# LPM/Sunshine Duration (%)    12 non-null int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 896.0+ bytes

# %%
suhu_dan_kelembaban.describe()
# Out:
#            Nomor  Temperatur Rata-rata (oC)  Temperatur Maksimal (oC)  \
# count  12.000000                  12.000000                 12.000000
# mean    6.500000                  23.516667                 29.183333
# std     3.605551                   0.353768                  0.669916
# min     1.000000                  23.000000                 28.200000
# 25%     3.750000                  23.300000                 28.675000
# 50%     6.500000                  23.400000                 29.200000
# 75%     9.250000                  23.750000                 29.575000
# max    12.000000                  24.200000                 30.500000
#
#        Temperatur Minimal (oC)  Jumlah Curah Hujan (mm)  Hari Hujan (hari)  \
# count                12.000000                12.000000          12.000000
# mean                 20.125000               191.541667          19.750000
# std                   0.623954               137.599481           6.552238
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8))
plt.plot(suhu_dan_kelembaban['Nomor'], label = 'Nomor')
plt.plot(suhu_dan_kelembaban['Temperatur Rata-rata (oC)'], label = 'Temperatur Rata-rata (oC)')
plt.plot(suhu_dan_kelembaban['Temperatur Maksimal (oC)'], label = 'Temperatur Maksimal (oC)')
plt.plot(suhu_dan_kelembaban['Temperatur Minimal (oC)'], label = 'Temperatur Minimal (oC)')
plt.plot(suhu_dan_kelembaban['Jumlah Curah Hujan (mm)'], label = 'Jumlah Curah Hujan (mm)')
plt.plot(suhu_dan_kelembaban['Hari Hujan (hari)'], label = 'Hari Hujan (hari)')
plt.plot(suhu_dan_kelembaban['LPM/Sunshine Duration (%)'], label = 'LPM/Sunshine Duration (%)')
plt.xlabel('Bulan(januari=0)')
plt.ylabel('Parameter')
plt.title('Plot of Each Parameter')
plt.legend();
plt.show()
